# %% [markdown]
# **Instructions:**
# 1. **For all questions after 10th, Please only use the data specified in the note given just below the question**
# 2. **You need to add answers in the same file i.e.  PDS_UberDriveProject_Questions.ipynb' and rename that file as 'Name_Date.ipynb'.You can mention the date on which you will be uploading/submitting the file.For e.g. if you plan to submit your assignment on 31-March, you can rename the file as 'STUDENTNAME_31-Mar-2020'**

# %% [markdown]
# # Load the necessary libraries. Import and load the dataset with a name uber_drives .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Get the Data
df_ub=pd.read_csv('uberdrive-1.csv')
df_ub
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# 1          Fort Pierce     5.0              NaN
# 2          Fort Pierce     4.8  Errand/Supplies
# 3          Fort Pierce     4.7          Meeting
# 4      West Palm Beach    63.7   Customer Visit
# ...                ...     ...              ...
# 1150           Karachi     0.7          Meeting
# 1151  Unknown Location     3.9   Temporary Site
# 1152  Unknown Location    16.2          Meeting
# 1153           Gampaha     6.4   Temporary Site
# 1154         Ilukwatta    48.2   Temporary Site
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## Q1. Show the last 10 records of the dataset. (2 point)

# %%
df_ub.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Karachi     2.8  Errand/Supplies
# 1146           Karachi     2.9  Errand/Supplies
# 1147           Karachi     4.6  Errand/Supplies
# 1148           Karachi     4.6          Meeting
# 1149           Karachi     0.8   Customer Visit
# 1150           Karachi     0.7          Meeting
# 1151  Unknown Location     3.9   Temporary Site
# 1152  Unknown Location    16.2          Meeting
# 1153           Gampaha     6.4   Temporary Site
# 1154         Ilukwatta    48.2   Temporary Site

# %% [markdown]
# ## Q2. Show the first 10 records of the dataset. (2 points)

# %%
df_ub.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# 5  West Palm Beach     4.3   Meal/Entertain
# 6       Palm Beach     7.1          Meeting
# 7             Cary     0.8          Meeting
# 8      Morrisville     8.3          Meeting
# 9         New York    16.5   Customer Visit

# %% [markdown]
# ## Q3. Show the dimension(number of rows and columns) of the dataset. (2 points)

# %%
df_ub
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# 1          Fort Pierce     5.0              NaN
# 2          Fort Pierce     4.8  Errand/Supplies
# 3          Fort Pierce     4.7          Meeting
# 4      West Palm Beach    63.7   Customer Visit
# ...                ...     ...              ...
# 1150           Karachi     0.7          Meeting
# 1151  Unknown Location     3.9   Temporary Site
# 1152  Unknown Location    16.2          Meeting
# 1153           Gampaha     6.4   Temporary Site
# 1154         Ilukwatta    48.2   Temporary Site
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## Q4. Show the size (Total number of elements) of the dataset. (2 points)

# %%
df_ub.size
# Out:
# 8085

# %% [markdown]
# ## Q5. Display the information about all the variables of the data set. (2 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
df_ub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## Q6. Check for missing values. (2 points) -  Note: Output should be boolean only.

# %%
df_ub.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## Q7. How many missing values are present? (2 points)
#
# #### Hint: Find out the total number of missing values across all the variables

# %%
df_ub.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %% [markdown]
# ## Q8. Get the summary of the original data. (2 points).
#
# #### Hint: Summary includes- Count,Mean, Std, Min, 25%,50%,75% and max
#
# #### Note:Outcome will contain only numerical column.

# %%
df_ub.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# ## Q9. Drop the missing values and store data in a new dataframe (name it"df") (2-points)
#
# #### Note: Dataframe "df" will not contain any missing value

# %%
df=df_ub.dropna()
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# 2          Fort Pierce     4.8  Errand/Supplies
# 3          Fort Pierce     4.7          Meeting
# 4      West Palm Beach    63.7   Customer Visit
# 5      West Palm Beach     4.3   Meal/Entertain
# ...                ...     ...              ...
# 1150           Karachi     0.7          Meeting
# 1151  Unknown Location     3.9   Temporary Site
# 1152  Unknown Location    16.2          Meeting
# 1153           Gampaha     6.4   Temporary Site
# 1154         Ilukwatta    48.2   Temporary Site
#
# [653 rows x 7 columns]

# %% [markdown]
# ## Q10. Check the information of the dataframe(df). (2 points)
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Q11. Get the unique start locations. (2 points)
# #### Note: This question is based on the dataframe with no 'NA' values
# #### Hint- You need to print the unique start locations place names in this and not the count.

# %%
set(df["START*"].tolist())
# Out:
# {'Apex',
#  'Arabi',
#  'Asheville',
#  'Austin',
#  'Banner Elk',
#  'Bellevue',
#  'Berkeley',
#  'Boone',
#  'Briar Meadow',
#  'Burtrose',
#  'CBD',
#  'Capitol One',
#  'Cary',
#  'Chalmette',
#  'Chapel Hill',
#  'Chessington',
#  'Colombo',
#  'Daytona Beach',
#  'Downtown',
#  'Durham',
#  'Eagan Park',
#  'East Austin',
#  'East Elmhurst',
#  'East Harlem',
#  'Eastgate',
#  'Edgehill Farms',
#  'El Cerrito',
#  'Elmhurst',
#  'Emeryville',
#  'Fairmont',
#  'Farmington Woods',
#  'Fayetteville Street',
#  'Financial District',
#  'Flatiron District',
#  'Florence',
#  'Fort Pierce',
#  'Fuquay-Varina',
#  'Galveston',
#  'Gampaha',
#  'Georgian Acres',
#  'Gulfton',
#  'Hazelwood',
#  "Hell's Kitchen",
#  'Heritage Pines',
#  'Holly Springs',
#  'Houston',
#  'Hudson Square',
#  'Huntington Woods',
#  'Ingleside',
#  'Islamabad',
#  'Jacksonville',
#  'Jamaica',
#  'Karachi',
#  'Katunayaka',
#  'Katunayake',
#  'Katy',
#  'Kenner',
#  'Kilarney Woods',
#  'Kissimmee',
#  'Krendle Woods',
#  'Lahore',
#  'Lake Reams',
#  'Lake Wellingborough',
#  'Latta',
#  'Lexington Park at Amberly',
#  'Long Island City',
#  'Lower Garden District',
#  'Lower Manhattan',
#  'Mcvan',
#  'Medical Centre',
#  'Menlo Park',
#  'Meredith',
#  'Meredith Townes',
#  'Metairie',
#  'Midtown',
#  'Midtown East',
#  'Morrisville',
#  'Mountain View',
#  'New Orleans',
#  'New York',
#  'Newark',
#  'Noorpur Shahan',
#  'North Austin',
#  'Northwoods',
#  'Nugegoda',
#  'Oakland',
#  'Old City',
#  'Orlando',
#  'Palo Alto',
#  'Parkway',
#  'Parkwood',
#  'Pontchartrain Shores',
#  'Port Bolivar',
#  'Preston',
#  'R?walpindi',
#  'Raleigh',
#  'Rawalpindi',
#  'Redmond',
#  'Renaissance',
#  'Ridgeland',
#  'Rose Hill',
#  'San Francisco',
#  'Santa Clara',
#  'Savon Height',
#  'Seaport',
#  'Seattle',
#  'Sharpstown',
#  'Soho',
#  'South Congress',
#  'Stonewater',
#  'Storyville',
#  'Sugar Land',
#  'Summerwinds',
#  'Sunnyvale',
#  'Tanglewood',
#  'The Drag',
#  'Topton',
#  'Townes at Everett Crossing',
#  'Tribeca',
#  'University District',
#  'Unknown Location',
#  'Washington Avenue',
#  'Waverly Place',
#  'Wayne Ridge',
#  'West Berkeley',
#  'West Palm Beach',
#  'West University',
#  'Weston',
#  'Westpark Place',
#  'Whitebridge',
#  'Winston Salem'}

# %% [markdown]
# ## Q12. What is the total number of unique start locations? (2 points)
# #### Note: Use the original dataframe without dropping 'NA' values

# %%
len(set(df["START*"].tolist()))
# Out:
# 131

# %% [markdown]
# ## Q13. What is the total number of unique stop locations. (2 points)
# #### Note: Use the original dataframe without dropping 'NA' values.

# %%
len(set(df["STOP*"].tolist()))
# Out:
# 137

# %% [markdown]
# ## Q14. Display all the Uber trips that has the starting point of San Francisco. (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint: You need to display the rows which has starting point of San Francisco. Try using loc function

# %%
df.loc[df['START*']=='San Francisco',['START_DATE*','END_DATE*','CATEGORY*','START*','STOP*','MILES*','PURPOSE*']]
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint:Popular means the place that is visited the most

# %%
df['START*'].value_counts().idxmax()
# Out:
# 'Cary'

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint: Popular means the place that is visited the most

# %%
df['STOP*'].value_counts().idxmax()
# Out:
# 'Cary'

# %% [markdown]
# ## Q17. List the most frequent route taken by Uber drivers. (3 points)
# #### Note: This question is based on the new dataframe with no 'na' values.
# #### Hint-Print the most frequent route taken by Uber drivers (Route= combination of START & END points present in the Data set). One may use Groupby function

# %%
route=df.groupby(['START*','STOP*'])
route.describe()
# Out:
#                                  MILES*                                        \
#                                   count        mean       std    min      25%
# START*        STOP*
# Apex          Cary                 10.0    5.940000  1.184342    4.7    5.425
#               Holly Springs         1.0    9.000000       NaN    9.0    9.000
# Arabi         Metairie              1.0   17.000000       NaN   17.0   17.000
# Asheville     Topton                1.0   91.800000       NaN   91.8   91.800
# Austin        Katy                  1.0  136.000000       NaN  136.0  136.000
# ...                                 ...         ...       ...    ...      ...
# Whitebridge   Wayne Ridge           4.0    7.975000  0.170783    7.8    7.875
#               Westpark Place        3.0    2.066667  0.152753    1.9    2.000
#               Whitebridge           2.0    2.400000  2.545584    0.6    1.500
#               Williamsburg Manor    1.0    8.300000       NaN    8.3    8.300
# Winston Salem Asheville             1.0  133.600000       NaN  133.6  133.600
#
#
#                                      50%     75%    max
# START*        STOP*
# Apex          Cary                  5.55    5.70    8.8
#               Holly Springs         9.00    9.00    9.0
# Arabi         Metairie             17.00   17.00   17.0
# Asheville     Topton               91.80   91.80   91.8
# Austin        Katy                136.00  136.00  136.0
# ...                                  ...     ...    ...
# Whitebridge   Wayne Ridge           7.95    8.05    8.2
#               Westpark Place        2.10    2.15    2.2
#               Whitebridge           2.40    3.30    4.2
#               Williamsburg Manor    8.30    8.30    8.3
# Winston Salem Asheville           133.60  133.60  133.6
#
# [239 rows x 8 columns]

# %% [markdown]
# ## Q18. Display all types of purposes for the trip in an array. (3 points)
# #### Note: This question is based on the new dataframe with no 'NA' values.

# %%
list((set(df['PURPOSE*']))) #liSt is a Also an array
# Out:
# ['Airport/Travel',
#  'Temporary Site',
#  'Charity ($)',
#  'Errand/Supplies',
#  'Meeting',
#  'Commute',
#  'Moving',
#  'Customer Visit',
#  'Meal/Entertain',
#  'Between Offices']

# %% [markdown]
# ## Q19. Plot a bar graph of Purpose vs Miles(Distance). (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint:You have to plot total/sum miles per purpose

# %%
plt.barplot()

# %% [markdown]
# ## Q20. Display a dataframe of Purpose and the distance travelled for that particular Purpose. (3 points)
# #### Note: Use the original dataframe without dropping "NA" values

# %%
sns.barplot(df_ub['PURPOSE*'],df_ub['MILES*'])

# %% [markdown]
# ## Q21. Plot number of trips vs Category of trips. (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint : You can make a countplot or barplot.

# %%
print(df_ub['CATEGORY*'].value_counts())
sns.countplot(df_ub['CATEGORY*'])
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %% [markdown]
# ## Q22. What is proportion of miles that are covered as Business trips and what is the proportion of miles that are covered as Personal trips? (3 points)
#
# ### Note:Use the original dataframe without dropping the 'NA' values. The proportion calculation  is with respect to the 'miles' variable.
#
# #### Hint: Proportion of miles covered as business trips= (Total Miles clocked as Business Trips)/ (Total Miles)
# #### Proportion of miles covered as personal trips= (Total Miles clocked as Personal Trips)/ (Total Miles)

# %%
df1=df_ub['CATEGORY*'].value_counts()

# %%
print(df1)
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
df2=groupby[]
# Out:
# 0        5.1
# 1        5.0
# 2        4.8
# 3        4.7
# 4       63.7
#         ...
# 1150     0.7
# 1151     3.9
# 1152    16.2
# 1153     6.4
# 1154    48.2
# Name: MILES*, Length: 1155, dtype: float64
